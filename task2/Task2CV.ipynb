# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif,mutual_info_classif
import matplotlib.pyplot as plt
import matplotlib
from sklearn.decomposition import PCA
import matplotlib.cm as cm
from sklearn import preprocessing
from sklearn.metrics import balanced_accuracy_score
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
import math
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
y = pd.read_csv("y_train.csv")
y = y.drop(['id'],axis=1)
X = pd.read_csv("X_train.csv")
X = X.drop(['id'],axis=1)

X_normal = X
y_normal = y

df_train = pd.concat([X,y],axis=1)

# %% [markdown]
# ## Downsampling

# %%
df_class0 = df_train[df_train['y']==0]
df_class1 = df_train[df_train['y']==1]
df_class2 = df_train[df_train['y']==2]

num0 = df_class0.shape[0]
num1 = df_class1.shape[0]
num2 = df_class2.shape[0]

df0_down = df_class0.sample(num0)
df1_down = df_class1.sample(num0)
df2_down = df_class2.sample(num0)

df_down = pd.concat([df0_down, df1_down, df2_down]).sample(frac=1)
X_down = df_down.iloc[:,0:1000]
y_down = df_down.iloc[:,1000:1001]

# %% [markdown]
# ## Upsampling

# %%
df_class0 = df_train[df_train['y']==0]
df_class1 = df_train[df_train['y']==1]
df_class2 = df_train[df_train['y']==2]

num0 = df_class0.shape[0]
num1 = df_class1.shape[0]
num2 = df_class2.shape[0]

df0_up = df_class0.sample(num1, replace=True)
df1_up = df_class1.sample(num1)
df2_up = df_class2.sample(num1, replace=True)

df_up = pd.concat([df0_up, df1_up, df2_up]).sample(frac=1)
X_up = df_up.iloc[:,0:1000]
y_up = df_up.iloc[:,1000:1001]

# %% [markdown]
# ## Loop

# %%
def myscoring(clf,X,y):
    pred = clf.predict(X)
    return balanced_accuracy_score(y, pred)

# %%
def calculate(ndu, stan, f):
    '''
    ndu = normal or downsampling or undersampling: Default/down/up
    stand = standartize True/False
    f = features selection (how many): Int
    '''
    
    # Which Dataset
    X = X_normal
    y = y_normal
        
    # Standardize 
    if (stan):
        scaler = preprocessing.StandardScaler().fit(X)
        X = scaler.transform(X)
        
    # Feature Selection
    X = SelectKBest(f_classif,k=f).fit_transform(X,np.ravel(y))
    
    X = pd.DataFrame(X).reset_index(drop=True)
    y = pd.DataFrame(y).reset_index(drop=True)
    
    # SVM
    for c in [0.1, 0.5, 0.7, 0.8, 0.9, 1, 1.1, 1.2, 1.3, 5, 10]:
        svc = svm.SVC(kernel='rbf',C=c, random_state=42, class_weight='balanced', decision_function_shape='ovo')
        scores = crossval(svc,X,y,scoring=myscoring,f=f)
        avg = np.average(np.array(scores))
        print(ndu,', stan=',stan,'f=',f,' => SVM: rbf, ovo, c=',c,' crossvalscore: ',avg)
    
    # SVM2
    for c in [0.1, 0.5, 0.7, 0.8, 0.9, 1, 1.1, 1.2, 1.3, 5, 10]:
        svc = svm.SVC(kernel='rbf',C=c, random_state=42, class_weight='balanced', decision_function_shape='ovr')
        scores = crossval(svc,X,y,scoring=myscoring,f=f)
        avg = np.average(np.array(scores))
        print(ndu,', stan=',stan,'f=',f,' => SVM: rbf, ovr, c=',c,' crossvalscore: ',avg)
    
    # Logistic Regression
    for solver in ['liblinear','sag','lbfgs']:
        lr = LogisticRegression(class_weight='balanced', solver=solver)
        scores = crossval(lr,X,y,scoring=myscoring,f=f)
        avg = np.average(np.array(scores))
        print(ndu,', stan=',stan,'f=',f,' => LogReg: solver=',solver,' crossvalscore: ',avg)
    
    # LDA
    for shrinkage in [0.5,0.88,0.75,0.99]:
        lda = LinearDiscriminantAnalysis(solver="lsqr", store_covariance=True,shrinkage=shrinkage)
        scores = crossval(lda,X,y,scoring=myscoring,f=f)
        avg = np.average(np.array(scores))
        print(ndu,', stan=',stan,'f=',f,' => LDA: shrinkage=',shrinkage,' crossvalscore: ',avg)
    
    # RF
    rf = RandomForestClassifier(random_state=0,class_weight="balanced")
    scores = crossval(rf,X,y,scoring=myscoring,f=f)
    avg = np.average(np.array(scores))
    print(ndu,', stan=',stan,'f=',f,' => RF: crossvalscore: ',avg)
    print('-----------------------------------------------------------------------------')

# %%
def crossval(clf, X, y, scoring,f):
    scores = []
    for i in range(0,5):
        
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=i)
        X_train = pd.DataFrame(X_train)
        X_val = pd.DataFrame(X_val)
        y_train = pd.DataFrame(y_train)
        y_val = pd.DataFrame(y_val)
        
        df_train = pd.concat([X_train,y_train],axis=1)
        df_class0 = df_train[df_train['y']==0]
        df_class1 = df_train[df_train['y']==1]
        df_class2 = df_train[df_train['y']==2]

        num1 = df_class1.shape[0]

        df0_resampled = df_class0.sample(num1, replace=True)
        df1_resampled = df_class1.sample(num1)
        df2_resampled = df_class2.sample(num1, replace=True)

        df_resampled = pd.concat([df0_resampled, df1_resampled, df2_resampled]).sample(frac=1)
        X_resampled = df_resampled.iloc[:,0:f]
        y_resampled = df_resampled.iloc[:,f:f+1]
        
        
        clf.fit(X_resampled,y_resampled)
        
        score_i = scoring(clf,X_val.to_numpy(),y_val.to_numpy())
        scores.append(score_i)
    
    return scores

# %%
for ndu in ['up']:
    for stan in [True,False]:
        for f in [10,50,75,100,200,500,1000]:
            calculate(ndu,stan,f)
# Out:
# up , stan= True f= 10  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6335803960416406
# up , stan= True f= 10  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.631126216251563
# up , stan= True f= 10  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6354173154899895
# up , stan= True f= 10  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6341351677327183
# up , stan= True f= 10  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6362332943253138
# up , stan= True f= 10  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6348839003254907
# up , stan= True f= 10  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6341666424945235
# up , stan= True f= 10  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.627155218148048
# up , stan= True f= 10  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6327306076911893
# up , stan= True f= 10  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6351245162618582
# up , stan= True f= 10  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6184150375676536
# up , stan= True f= 10  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6272232681388564
# up , stan= True f= 10  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.633977857917865
# up , stan= True f= 10  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6336231422062691
# up , stan= True f= 10  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6318721892743632
# up , stan= True f= 10  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6351728778020669
# up , stan= True f= 10  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6292241741995538
# up , stan= True f= 10  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6337622878456309
# up , stan= True f= 10  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.631699497241444
# up , stan= True f= 10  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6344964292580044
# up , stan= True f= 10  => SVM: rbf, ovr, c= 5  crossvalscore:  0.628874585626698
# up , stan= True f= 10  => SVM: rbf, ovr, c= 10  crossvalscore:  0.62517126661475
# up , stan= True f= 10  => LogReg: solver= liblinear  crossvalscore:  0.6233009119193333
# up , stan= True f= 10  => LogReg: solver= sag  crossvalscore:  0.6360236801027793
# up , stan= True f= 10  => LogReg: solver= lbfgs  crossvalscore:  0.6396275394637186
# up , stan= True f= 10  => LDA: shrinkage= 0.5  crossvalscore:  0.6265725492546823
# up , stan= True f= 10  => LDA: shrinkage= 0.88  crossvalscore:  0.6201374329466485
# up , stan= True f= 10  => LDA: shrinkage= 0.75  crossvalscore:  0.6234358240363329
# up , stan= True f= 10  => LDA: shrinkage= 0.99  crossvalscore:  0.6192068071253292
# up , stan= True f= 10  => RF: crossvalscore:  0.5330885886548014
# -----------------------------------------------------------------------------
# up , stan= True f= 50  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6418688526009599
# up , stan= True f= 50  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.655561825311178
# up , stan= True f= 50  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6488545925900838
# up , stan= True f= 50  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.651610568533204
# up , stan= True f= 50  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.657241386184195
# up , stan= True f= 50  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6552993075974194
# up , stan= True f= 50  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6621266919879252
# up , stan= True f= 50  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6679217532277837
# up , stan= True f= 50  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6622976227957589
# up , stan= True f= 50  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6537293153264983
# up , stan= True f= 50  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6365474459703371
# up , stan= True f= 50  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6429393241464185
# up , stan= True f= 50  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6524198950575093
# up , stan= True f= 50  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6613401050772072
# up , stan= True f= 50  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6565333622735178
# up , stan= True f= 50  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6612881249986581
# up , stan= True f= 50  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6548047099985868
# up , stan= True f= 50  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6556206117984547
# up , stan= True f= 50  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6592230606665338
# up , stan= True f= 50  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6585530000637491
# up , stan= True f= 50  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6470641044047496
# up , stan= True f= 50  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6243521215638721
# up , stan= True f= 50  => LogReg: solver= liblinear  crossvalscore:  0.6419451034792656
# up , stan= True f= 50  => LogReg: solver= sag  crossvalscore:  0.6436275968087594
# up , stan= True f= 50  => LogReg: solver= lbfgs  crossvalscore:  0.6448909552153564
# up , stan= True f= 50  => LDA: shrinkage= 0.5  crossvalscore:  0.6515232291922328
# up , stan= True f= 50  => LDA: shrinkage= 0.88  crossvalscore:  0.6395612935402625
# up , stan= True f= 50  => LDA: shrinkage= 0.75  crossvalscore:  0.6449006940438002
# up , stan= True f= 50  => LDA: shrinkage= 0.99  crossvalscore:  0.6322969336774785
# up , stan= True f= 50  => RF: crossvalscore:  0.5466791980318261
# -----------------------------------------------------------------------------
# up , stan= True f= 75  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6537892854724501
# up , stan= True f= 75  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6555718515641769
# up , stan= True f= 75  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6624025035844501
# up , stan= True f= 75  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6627238377445213
# up , stan= True f= 75  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6560420660837362
# up , stan= True f= 75  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6578410224105242
# up , stan= True f= 75  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6564869254887447
# up , stan= True f= 75  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6537357910854974
# up , stan= True f= 75  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6606433224726248
# up , stan= True f= 75  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6460799570913688
# up , stan= True f= 75  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6295229383209275
# up , stan= True f= 75  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6454158011317409
# up , stan= True f= 75  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6535392410659628
# up , stan= True f= 75  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6553645234515721
# up , stan= True f= 75  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6606224932874541
# up , stan= True f= 75  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6583788717910092
# up , stan= True f= 75  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6596752460543203
# up , stan= True f= 75  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6589691659187684
# up , stan= True f= 75  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6553297661691555
# up , stan= True f= 75  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6545834074982714
# up , stan= True f= 75  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6480510748327124
# up , stan= True f= 75  => SVM: rbf, ovr, c= 10  crossvalscore:  0.633381352756038
# up , stan= True f= 75  => LogReg: solver= liblinear  crossvalscore:  0.6433191015971762
# up , stan= True f= 75  => LogReg: solver= sag  crossvalscore:  0.636639394437054
# up , stan= True f= 75  => LogReg: solver= lbfgs  crossvalscore:  0.637562919212751
# up , stan= True f= 75  => LDA: shrinkage= 0.5  crossvalscore:  0.649642723039656
# up , stan= True f= 75  => LDA: shrinkage= 0.88  crossvalscore:  0.6361390628848094
# up , stan= True f= 75  => LDA: shrinkage= 0.75  crossvalscore:  0.6420386401315825
# up , stan= True f= 75  => LDA: shrinkage= 0.99  crossvalscore:  0.6289682327829177
# up , stan= True f= 75  => RF: crossvalscore:  0.52871695865107
# -----------------------------------------------------------------------------
# up , stan= True f= 100  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6442261309292662
# up , stan= True f= 100  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6569723372382336
# up , stan= True f= 100  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6627319196767203
# up , stan= True f= 100  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6584903601753107
# up , stan= True f= 100  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6602792804730279
# up , stan= True f= 100  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6621585468965445
# up , stan= True f= 100  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6572800964733566
# up , stan= True f= 100  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6549819032011723
# up , stan= True f= 100  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.648109281478196
# up , stan= True f= 100  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6332145815515152
# up , stan= True f= 100  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6171389772503806
# up , stan= True f= 100  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6430437564566445
# up , stan= True f= 100  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.661747360822282
# up , stan= True f= 100  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6585923125091544
# up , stan= True f= 100  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6641478535618222
# up , stan= True f= 100  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6537446953634379
# up , stan= True f= 100  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6555279453139423
# up , stan= True f= 100  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6564611498234995
# up , stan= True f= 100  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6643821281140312
# up , stan= True f= 100  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6506804841621422
# up , stan= True f= 100  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6308256706921421
# up , stan= True f= 100  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6138559087916831
# up , stan= True f= 100  => LogReg: solver= liblinear  crossvalscore:  0.639757559097804
# up , stan= True f= 100  => LogReg: solver= sag  crossvalscore:  0.6332494316200078
# up , stan= True f= 100  => LogReg: solver= lbfgs  crossvalscore:  0.6301646988847203
# up , stan= True f= 100  => LDA: shrinkage= 0.5  crossvalscore:  0.646845800145291
# up , stan= True f= 100  => LDA: shrinkage= 0.88  crossvalscore:  0.6364914240082965
# up , stan= True f= 100  => LDA: shrinkage= 0.75  crossvalscore:  0.645843770225847
# up , stan= True f= 100  => LDA: shrinkage= 0.99  crossvalscore:  0.6274887423068953
# up , stan= True f= 100  => RF: crossvalscore:  0.5401742062570197
# -----------------------------------------------------------------------------
# up , stan= True f= 200  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.662580148361003
# up , stan= True f= 200  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6791069303784495
# up , stan= True f= 200  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6588954620937899
# up , stan= True f= 200  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6760850487435396
# up , stan= True f= 200  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6662933720664108
# up , stan= True f= 200  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6656477975948915
# up , stan= True f= 200  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6636487164137553
# up , stan= True f= 200  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6646494982464549
# up , stan= True f= 200  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6599986388406267
# up , stan= True f= 200  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6377613455230959
# up , stan= True f= 200  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6204307940882715
# up , stan= True f= 200  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6600039663770026
# up , stan= True f= 200  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6691687870541182
# up , stan= True f= 200  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6713265283245926
# up , stan= True f= 200  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6734725844117606
# up , stan= True f= 200  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6663209640837852
# up , stan= True f= 200  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6613367078619659
# up , stan= True f= 200  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6632613962862104
# up , stan= True f= 200  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6636281188329438
# up , stan= True f= 200  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6622935541643795
# up , stan= True f= 200  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6297250438908863
# up , stan= True f= 200  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6222594324050366
# up , stan= True f= 200  => LogReg: solver= liblinear  crossvalscore:  0.6411899718738787
# up , stan= True f= 200  => LogReg: solver= sag  crossvalscore:  0.6287113049206188
# up , stan= True f= 200  => LogReg: solver= lbfgs  crossvalscore:  0.6376421057601555
# up , stan= True f= 200  => LDA: shrinkage= 0.5  crossvalscore:  0.6634918418253997
# up , stan= True f= 200  => LDA: shrinkage= 0.88  crossvalscore:  0.6461421347839167
# up , stan= True f= 200  => LDA: shrinkage= 0.75  crossvalscore:  0.6500750513924907
# up , stan= True f= 200  => LDA: shrinkage= 0.99  crossvalscore:  0.6299296801072249
# up , stan= True f= 200  => RF: crossvalscore:  0.5213327305462785
# -----------------------------------------------------------------------------
# up , stan= True f= 500  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6636765049636599
# up , stan= True f= 500  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6857808252538871
# up , stan= True f= 500  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6823529580486155
# up , stan= True f= 500  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6798590632481931
# up , stan= True f= 500  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6716115748391607
# up , stan= True f= 500  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6807104624940253
# up , stan= True f= 500  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6690076862017287
# up , stan= True f= 500  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6742243320065471
# up , stan= True f= 500  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6645911400593422
# up , stan= True f= 500  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6280890595437668
# up , stan= True f= 500  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6124890650262165
# up , stan= True f= 500  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6658261016168234
# up , stan= True f= 500  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6839313017450883
# up , stan= True f= 500  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.683928338094884
# up , stan= True f= 500  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.677400973479154
# up , stan= True f= 500  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6773579031084314
# up , stan= True f= 500  => SVM: rbf, ovr, c= 1  crossvalscore:  0.670555094794914
# up , stan= True f= 500  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6710284419568685
# up , stan= True f= 500  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.673417460951136
# up , stan= True f= 500  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6614185388378363
# up , stan= True f= 500  => SVM: rbf, ovr, c= 5  crossvalscore:  0.62574056503981
# up , stan= True f= 500  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6156898732709355
# up , stan= True f= 500  => LogReg: solver= liblinear  crossvalscore:  0.6299901427160461
# up , stan= True f= 500  => LogReg: solver= sag  crossvalscore:  0.6229230148864298
# up , stan= True f= 500  => LogReg: solver= lbfgs  crossvalscore:  0.6180336181043214
# up , stan= True f= 500  => LDA: shrinkage= 0.5  crossvalscore:  0.6841023111247055
# up , stan= True f= 500  => LDA: shrinkage= 0.88  crossvalscore:  0.6572083890212288
# up , stan= True f= 500  => LDA: shrinkage= 0.75  crossvalscore:  0.6703271041396398
# up , stan= True f= 500  => LDA: shrinkage= 0.99  crossvalscore:  0.6391297281369248
# up , stan= True f= 500  => RF: crossvalscore:  0.5225484649315196
# -----------------------------------------------------------------------------
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6788931306395772
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6966579550155331
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6826140762216852
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6809001444768852
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6719839709524918
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6719330470546014
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6652474163597477
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6682156659777246
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.67134567830048
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6229434460494746
# up , stan= True f= 1000  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6186939781028227
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6779430363195142
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6914327927381958
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6833446541207793
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6792585753430088
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6808922210739599
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 1  crossvalscore:  0.667944520126891
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6702739329596039
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6698305927204713
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6624181690699003
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6284363082462099
# up , stan= True f= 1000  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6187636175575768
# up , stan= True f= 1000  => LogReg: solver= liblinear  crossvalscore:  0.6119144056329777
# up , stan= True f= 1000  => LogReg: solver= sag  crossvalscore:  0.6242502133468273
# up , stan= True f= 1000  => LogReg: solver= lbfgs  crossvalscore:  0.6093687594233456
# up , stan= True f= 1000  => LDA: shrinkage= 0.5  crossvalscore:  0.7005158694722808
# up , stan= True f= 1000  => LDA: shrinkage= 0.88  crossvalscore:  0.6784384325749024
# up , stan= True f= 1000  => LDA: shrinkage= 0.75  crossvalscore:  0.6879200066131314
# up , stan= True f= 1000  => LDA: shrinkage= 0.99  crossvalscore:  0.6491589571919028
# up , stan= True f= 1000  => RF: crossvalscore:  0.5141442689867839
# -----------------------------------------------------------------------------
# up , stan= False f= 10  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6251732167176021
# up , stan= False f= 10  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6398262405318409
# up , stan= False f= 10  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6260327522080672
# up , stan= False f= 10  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6428018110707221
# up , stan= False f= 10  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6372540998585219
# up , stan= False f= 10  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6330052533359318
# up , stan= False f= 10  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6336605924255292
# up , stan= False f= 10  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6330570707909068
# up , stan= False f= 10  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6387193992812233
# up , stan= False f= 10  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6255393694411837
# up , stan= False f= 10  => SVM: rbf, ovo, c= 10  crossvalscore:  0.611906587450538
# up , stan= False f= 10  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.633227800165917
# up , stan= False f= 10  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6317492471154047
# up , stan= False f= 10  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.632994808691264
# up , stan= False f= 10  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6359248491963514
# up , stan= False f= 10  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6357674895228138
# up , stan= False f= 10  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6362344918415833
# up , stan= False f= 10  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6408201936547914
# up , stan= False f= 10  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6387314082560596
# up , stan= False f= 10  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6389229977730986
# up , stan= False f= 10  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6213629410588135
# up , stan= False f= 10  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6059420340970705
# up , stan= False f= 10  => LogReg: solver= liblinear  crossvalscore:  0.6276164228320689
# up , stan= False f= 10  => LogReg: solver= sag  crossvalscore:  0.6369120477586753
# up , stan= False f= 10  => LogReg: solver= lbfgs  crossvalscore:  0.6324968100819583
# up , stan= False f= 10  => LDA: shrinkage= 0.5  crossvalscore:  0.6255530942877685
# up , stan= False f= 10  => LDA: shrinkage= 0.88  crossvalscore:  0.6233245190991376
# up , stan= False f= 10  => LDA: shrinkage= 0.75  crossvalscore:  0.6250156551681936
# up , stan= False f= 10  => LDA: shrinkage= 0.99  crossvalscore:  0.6249716841959858
# up , stan= False f= 10  => RF: crossvalscore:  0.5407222544516235
# -----------------------------------------------------------------------------
# up , stan= False f= 50  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6425038877591013
# up , stan= False f= 50  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6508794140632963
# up , stan= False f= 50  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.655454180389288
# up , stan= False f= 50  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6537934709224313
# up , stan= False f= 50  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6596601713459906
# up , stan= False f= 50  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6577204032074174
# up , stan= False f= 50  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6582647795148209
# up , stan= False f= 50  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6583030959287096
# up , stan= False f= 50  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6557323906792326
# up , stan= False f= 50  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6449076104125007
# up , stan= False f= 50  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6206807075962063
# up , stan= False f= 50  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6488715233818374
# up , stan= False f= 50  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6562918497451575
# up , stan= False f= 50  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6557747856637206
# up , stan= False f= 50  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.654038837061338
# up , stan= False f= 50  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6515225302082398
# up , stan= False f= 50  => SVM: rbf, ovr, c= 1  crossvalscore:  0.660948880789411
# up , stan= False f= 50  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.655566498713371
# up , stan= False f= 50  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6575381206999176
# up , stan= False f= 50  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6606831189905911
# up , stan= False f= 50  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6484592579759909
# up , stan= False f= 50  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6240433048363021
# up , stan= False f= 50  => LogReg: solver= liblinear  crossvalscore:  0.6454243559067214
# up , stan= False f= 50  => LogReg: solver= sag  crossvalscore:  0.6453046520893847
# up , stan= False f= 50  => LogReg: solver= lbfgs  crossvalscore:  0.6399269581176374
# up , stan= False f= 50  => LDA: shrinkage= 0.5  crossvalscore:  0.6559135427322851
# up , stan= False f= 50  => LDA: shrinkage= 0.88  crossvalscore:  0.6415852677982326
# up , stan= False f= 50  => LDA: shrinkage= 0.75  crossvalscore:  0.6388356022615715
# up , stan= False f= 50  => LDA: shrinkage= 0.99  crossvalscore:  0.6312601446212451
# up , stan= False f= 50  => RF: crossvalscore:  0.5466268520034032
# -----------------------------------------------------------------------------
# up , stan= False f= 75  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6483978618029935
# up , stan= False f= 75  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.657204203630617
# up , stan= False f= 75  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6575730882835561
# up , stan= False f= 75  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6590503907665817
# up , stan= False f= 75  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6498835475486874
# up , stan= False f= 75  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6589493123620453
# up , stan= False f= 75  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6528559789602661
# up , stan= False f= 75  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6531313325891767
# up , stan= False f= 75  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6632424259479116
# up , stan= False f= 75  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6387082273908421
# up , stan= False f= 75  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6246925747713477
# up , stan= False f= 75  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6477105342677902
# up , stan= False f= 75  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6540621328051841
# up , stan= False f= 75  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6558402185034373
# up , stan= False f= 75  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6587404502565322
# up , stan= False f= 75  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6521103181635965
# up , stan= False f= 75  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6508844366161648
# up , stan= False f= 75  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6604546329475085
# up , stan= False f= 75  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.655124286322107
# up , stan= False f= 75  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6574221568424833
# up , stan= False f= 75  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6467128162219804
# up , stan= False f= 75  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6274842578517181
# up , stan= False f= 75  => LogReg: solver= liblinear  crossvalscore:  0.6414411114410985
# up , stan= False f= 75  => LogReg: solver= sag  crossvalscore:  0.6348777312586679
# up , stan= False f= 75  => LogReg: solver= lbfgs  crossvalscore:  0.6343369041294441
# up , stan= False f= 75  => LDA: shrinkage= 0.5  crossvalscore:  0.6508753741426232
# up , stan= False f= 75  => LDA: shrinkage= 0.88  crossvalscore:  0.6390865331652427
# up , stan= False f= 75  => LDA: shrinkage= 0.75  crossvalscore:  0.6434176123740702
# up , stan= False f= 75  => LDA: shrinkage= 0.99  crossvalscore:  0.6275489435525646
# up , stan= False f= 75  => RF: crossvalscore:  0.5253160160478533
# -----------------------------------------------------------------------------
# up , stan= False f= 100  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6427040123751818
# up , stan= False f= 100  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6560912342275593
# up , stan= False f= 100  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6555574436272334
# up , stan= False f= 100  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6527064092729009
# up , stan= False f= 100  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6624543198896945
# up , stan= False f= 100  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6534108575229683
# up , stan= False f= 100  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6531457737693946
# up , stan= False f= 100  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6557949387939991
# up , stan= False f= 100  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6554792725317797
# up , stan= False f= 100  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6422747003143099
# up , stan= False f= 100  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6149840865988485
# up , stan= False f= 100  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6455838790104015
# up , stan= False f= 100  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6587948992365085
# up , stan= False f= 100  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6554978623946528
# up , stan= False f= 100  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6555492072404754
# up , stan= False f= 100  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6512052205806367
# up , stan= False f= 100  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6516164875772222
# up , stan= False f= 100  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6540689447763012
# up , stan= False f= 100  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6616997516722923
# up , stan= False f= 100  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6545003664252202
# up , stan= False f= 100  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6402289899153348
# up , stan= False f= 100  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6126945190374087
# up , stan= False f= 100  => LogReg: solver= liblinear  crossvalscore:  0.6416754713448659
# up , stan= False f= 100  => LogReg: solver= sag  crossvalscore:  0.6332369274804862
# up , stan= False f= 100  => LogReg: solver= lbfgs  crossvalscore:  0.6395166111811738
# up , stan= False f= 100  => LDA: shrinkage= 0.5  crossvalscore:  0.6505636059035806
# up , stan= False f= 100  => LDA: shrinkage= 0.88  crossvalscore:  0.6396655005299184
# up , stan= False f= 100  => LDA: shrinkage= 0.75  crossvalscore:  0.647831239568139
# up , stan= False f= 100  => LDA: shrinkage= 0.99  crossvalscore:  0.6238559299624387
# up , stan= False f= 100  => RF: crossvalscore:  0.532239333287559
# -----------------------------------------------------------------------------
# up , stan= False f= 200  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6542827809991419
# up , stan= False f= 200  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.670032287288062
# up , stan= False f= 200  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6674811542367256
# up , stan= False f= 200  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6715639919101616
# up , stan= False f= 200  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6633287365829921
# up , stan= False f= 200  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6686136396204649
# up , stan= False f= 200  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6596795797867653
# up , stan= False f= 200  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.66648976915908
# up , stan= False f= 200  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6599405708942083
# up , stan= False f= 200  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6406969177771585
# up , stan= False f= 200  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6135357734350447
# up , stan= False f= 200  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6497669221658889
# up , stan= False f= 200  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6751597236468041
# up , stan= False f= 200  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6648390183105113
# up , stan= False f= 200  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6660597810305522
# up , stan= False f= 200  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.666128109278374
# up , stan= False f= 200  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6674291561251793
# up , stan= False f= 200  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6728464885161863
# up , stan= False f= 200  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6754180683622837
# up , stan= False f= 200  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.662909987380189
# up , stan= False f= 200  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6388440510231803
# up , stan= False f= 200  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6178821930750245
# up , stan= False f= 200  => LogReg: solver= liblinear  crossvalscore:  0.6508801559974815
# up , stan= False f= 200  => LogReg: solver= sag  crossvalscore:  0.6351288030546374
# up , stan= False f= 200  => LogReg: solver= lbfgs  crossvalscore:  0.6285621359311327
# up , stan= False f= 200  => LDA: shrinkage= 0.5  crossvalscore:  0.6599546129599281
# up , stan= False f= 200  => LDA: shrinkage= 0.88  crossvalscore:  0.6437852390012023
# up , stan= False f= 200  => LDA: shrinkage= 0.75  crossvalscore:  0.6589395609874478
# up , stan= False f= 200  => LDA: shrinkage= 0.99  crossvalscore:  0.6311215936523835
# up , stan= False f= 200  => RF: crossvalscore:  0.5336679713916581
# -----------------------------------------------------------------------------
# up , stan= False f= 500  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6650178498959392
# up , stan= False f= 500  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.689733994129431
# up , stan= False f= 500  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6865548360843781
# up , stan= False f= 500  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6720130023664221
# up , stan= False f= 500  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6753024673078314
# up , stan= False f= 500  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6727571447519034
# up , stan= False f= 500  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.6745702397533127
# up , stan= False f= 500  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6775295475925003
# up , stan= False f= 500  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6710240516814869
# up , stan= False f= 500  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6275247724989151
# up , stan= False f= 500  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6153252664300906
# up , stan= False f= 500  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6597221203709698
# up , stan= False f= 500  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.6885695965874822
# up , stan= False f= 500  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6848733642361158
# up , stan= False f= 500  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6823848977631308
# up , stan= False f= 500  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.6807644525499968
# up , stan= False f= 500  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6744367324723177
# up , stan= False f= 500  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6732178400033267
# up , stan= False f= 500  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6768433751688469
# up , stan= False f= 500  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6741193036934456
# up , stan= False f= 500  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6249707855141782
# up , stan= False f= 500  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6153791939356252
# up , stan= False f= 500  => LogReg: solver= liblinear  crossvalscore:  0.6320647168360216
# up , stan= False f= 500  => LogReg: solver= sag  crossvalscore:  0.6218497911749921
# up , stan= False f= 500  => LogReg: solver= lbfgs  crossvalscore:  0.6080039646929662
# up , stan= False f= 500  => LDA: shrinkage= 0.5  crossvalscore:  0.685042441671276
# up , stan= False f= 500  => LDA: shrinkage= 0.88  crossvalscore:  0.6548877370640385
# up , stan= False f= 500  => LDA: shrinkage= 0.75  crossvalscore:  0.6676102169869471
# up , stan= False f= 500  => LDA: shrinkage= 0.99  crossvalscore:  0.6374091037096254
# up , stan= False f= 500  => RF: crossvalscore:  0.5212150516990142
# -----------------------------------------------------------------------------
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 0.1  crossvalscore:  0.6783164890593077
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 0.5  crossvalscore:  0.6978213868125773
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 0.7  crossvalscore:  0.6945958617030196
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 0.8  crossvalscore:  0.6981985259327883
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 0.9  crossvalscore:  0.6948542655017587
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 1  crossvalscore:  0.6873382752545488
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 1.1  crossvalscore:  0.684646305360382
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 1.2  crossvalscore:  0.6802637732896818
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 1.3  crossvalscore:  0.6808204497464343
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 5  crossvalscore:  0.6444583300576358
# up , stan= False f= 1000  => SVM: rbf, ovo, c= 10  crossvalscore:  0.6372952714995338
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 0.1  crossvalscore:  0.6785031895677315
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 0.5  crossvalscore:  0.7034321849880079
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 0.7  crossvalscore:  0.6960106639350492
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 0.8  crossvalscore:  0.6914801577403533
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 0.9  crossvalscore:  0.693047050305503
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 1  crossvalscore:  0.6838439900500666
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 1.1  crossvalscore:  0.6875095840669557
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 1.2  crossvalscore:  0.6831855885597822
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 1.3  crossvalscore:  0.6808664285503198
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 5  crossvalscore:  0.6426510941040472
# up , stan= False f= 1000  => SVM: rbf, ovr, c= 10  crossvalscore:  0.6334514122224003
# up , stan= False f= 1000  => LogReg: solver= liblinear  crossvalscore:  0.6170032714561865
# up , stan= False f= 1000  => LogReg: solver= sag  crossvalscore:  0.6221921544588233
# up , stan= False f= 1000  => LogReg: solver= lbfgs  crossvalscore:  0.602157353518525
# up , stan= False f= 1000  => LDA: shrinkage= 0.5  crossvalscore:  0.6953932055229245
# up , stan= False f= 1000  => LDA: shrinkage= 0.88  crossvalscore:  0.6776691594688631
# up , stan= False f= 1000  => LDA: shrinkage= 0.75  crossvalscore:  0.6892037332174261
# up , stan= False f= 1000  => LDA: shrinkage= 0.99  crossvalscore:  0.6421220197109433
# up , stan= False f= 1000  => RF: crossvalscore:  0.5246721010287413
# -----------------------------------------------------------------------------
